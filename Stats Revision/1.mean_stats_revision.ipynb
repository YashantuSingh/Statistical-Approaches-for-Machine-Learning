# %%
a=[1,4,7,9]
a_sum=sum(a)
print("sum:",a_sum)
print("count:",len(a))
# Out:
# sum: 21
# count: 4

# %%
b=[14,42,17,19]
x=sum(b)
y=len(b)
print("sum:",x)
print("count:",y)
# Out:
# sum: 92
# count: 4

# %%
#Mean

p=[24,73,56,28,19,18,17,34,71]
x=sum(p)
y=len(p)
z=x/y
print("sum:",x)
print("count:",y)
print("Mean:",z)
# Out:
# sum: 340
# count: 9
# Mean: 37.77777777777778

# %%
q=[24,19,18,17,34,71]
x=sum(q)
y=len(q)
z=x/y
print("sum:",x)
print("count:",y)
print("Mean:",z)
# Out:
# sum: 183
# count: 6
# Mean: 30.5

# %%
a=[3,6,4,8]
x=sum(a)
print("sum:",x)
# Out:
# sum: 21

# %%
a=[3,6,4,8]
x=len(a)
y=sum(a)
z=y/x
print("Mean:",z)
# Out:
# Mean: 5.25

# %%
s=[13,63,42,81]
f=sum(s)
g=len(s)
h=f/g
print("Sum:",f)
print("len:",g)
print("mean:",h)
# Out:
# Sum: 199
# len: 4
# mean: 49.75

# %%
#Median
