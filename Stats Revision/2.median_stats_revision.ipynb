# %%
#Median

k=[2,4,5,6,8,9,12,14,15,17,19]
print(f"{k[0]}\n{k[1]}\n{k[2]}\n{k[3]}\n{k[4]}\n{k[5]}\n{k[6]}\n{k[7]}\n{k[8]}\n{k[9]}\n{k[10]}")
# Out:
# 2
# 4
# 5
# 6
# 8
# 9
# 12
# 14
# 15
# 17
# 19

# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
n=len(k)
print("len:",n)
# Out:
# len: 11

# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
n=len(k)
midpos=n//2
print("Mid Position:",midpos)
print("Value of Middle Position:",k[midpos])
# Out:
# Mid Position: 5
# Value of Middle Position: 9

# %%
l=[12,14,15,16,18,19,22,24,25,27,29,39,40,42,45,47,49]
n=len(l)
midpos=n//2
print(l[0:18])
print("len:",n)
print("Mid Pos:",midpos)
print("Value of Mid Pos:",l[midpos])
# Out:
# [12, 14, 15, 16, 18, 19, 22, 24, 25, 27, 29, 39, 40, 42, 45, 47, 49]
# len: 17
# Mid Pos: 8
# Value of Mid Pos: 25

# %%
m=[12,14,15]
n=len(m)
midpos=n//2
print(m[0:])
print('len:',n)
print('Mid Pos:',midpos) 
print('Value of Mid Pos:',m[midpos])
# Out:
# [12, 14, 15]
# len: 3
# Mid Pos: 1
# Value of Mid Pos: 14

# %%
m=[12,14,15,16,17]
n=len(m)
midpos=n//2
print(m[0:])
print('len:',n)
print('Mid Pos:',midpos) 
print('Value of Mid Pos:',m[midpos])
# Out:
# [12, 14, 15, 16, 17]
# len: 5
# Mid Pos: 2
# Value of Mid Pos: 15

# %%
p=[12,14,15,16]
n=len(p)
midpos1,midpos2=n//2-1,n//2
print(p[0:])
print('len:',n)
print(f"midpos1: {midpos1}\nmidpos2: {midpos2}")
print(f"value of midpos1:{p[midpos1]}\nvalue of midpos2:{p[midpos2]}")
# Out:
# [12, 14, 15, 16]
# len: 4
# midpos1: 1
# midpos2: 2
# value of midpos1:14
# value of midpos2:15

# %%
q=[12,14,15,16,18,19]
n=len(q)
midpos1,midpos2=n//2-1,n//2
print(q[0:])
print('len:',n)
print(f"midpos1: {midpos1}\nmidpos2: {midpos2}")
print(f"value of midpos1:{q[midpos1]}\nvalue of midpos2:{q[midpos2]}")
# Out:
# [12, 14, 15, 16, 18, 19]
# len: 6
# midpos1: 2
# midpos2: 3
# value of midpos1:15
# value of midpos2:16

# %%
r=[12,14,15,16,18,19,20,22]
n=len(r)
print(r[0:])
print('len:',n)
print(f"midpos1: {midpos1}\nmidpos2: {midpos2}")
print(f"value of midpos1:{r[midpos1]}\nvalue of midpos2:{r[midpos2]}")
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22]
# len: 8
# midpos1: 2
# midpos2: 3
# value of midpos1:15
# value of midpos2:16

# %%
r=[12,14,15,16,18,19,20,22]
n=len(r)
midpos1=n//2-1
midpos2=n//2
print(r[0:])
print(midpos1,midpos2)
print(r[midpos1],r[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22]
# 3 4
# 16 18

# %%
s=[12,14,15,16,18,19,20,22,24,27]
n=len(s)
midpos1=n//2-1
midpos2=n//2
print(s[0:])
print("Midpose",midpos1,midpos2)
print("Midpose value",s[midpos1],s[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 27]
# Midpose 4 5
# Midpose value 18 19
